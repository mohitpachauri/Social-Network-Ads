# %% [markdown]
# ## IMPORTING PACKAGES ##
#
# #### pandas , numpy : data analysis
# #### matplotlib , seaborn : data visualisation
# #### sklearn : predicting purchase

# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns; sns.set()
from matplotlib.pyplot import style ; style.use('ggplot')

# %%
ads = pd.read_csv('Social_Network_Ads.csv')
ads.head()
# Out:
#     User ID  Gender  Age  EstimatedSalary  Purchased
# 0  15624510    Male   19            19000          0
# 1  15810944    Male   35            20000          0
# 2  15668575  Female   26            43000          0
# 3  15603246  Female   27            57000          0
# 4  15804002    Male   19            76000          0

# %% [markdown]
# ## DATA VISUALISATION ##

# %%
sns.scatterplot(ads.Age,ads.EstimatedSalary,hue=ads.Purchased)

# %%
# %matplotlib inline
plt.figure(figsize=(18,16))
sns.scatterplot(ads.Age,ads.EstimatedSalary,hue=ads.Purchased,style=ads.Gender)
plt.show()

# %% [markdown]
# ### interpretation of graph ###
#
# #### SALARY below 90k and AGE below 45 no PURCHASE irrespective of GENDER ####

# %% [markdown]
# #### Using CART Algorithms ####

# %%
from sklearn.tree import DecisionTreeClassifier as DTC
dt = DTC()

# %%
ads.Gender = ads.Gender.map({'Male':0,'Female':1})

# %%
ads.head()
# Out:
#     User ID  Gender  Age  EstimatedSalary  Purchased
# 0  15624510       0   19            19000          0
# 1  15810944       0   35            20000          0
# 2  15668575       1   26            43000          0
# 3  15603246       1   27            57000          0
# 4  15804002       0   19            76000          0

# %%
x = ads.iloc[:,1:-1].values
y = ads.iloc[:,-1].values

# %%
from sklearn.model_selection import train_test_split as tts
x_train,x_test,y_train,y_test = tts(x,y)

# %%
dt.fit(x_train,y_train)
# Out:
# DecisionTreeClassifier(class_weight=None, criterion='gini', max_depth=None,
#                        max_features=None, max_leaf_nodes=None,
#                        min_impurity_decrease=0.0, min_impurity_split=None,
#                        min_samples_leaf=1, min_samples_split=2,
#                        min_weight_fraction_leaf=0.0, presort=False,
#                        random_state=None, splitter='best')

# %%
dt.score(x_test,y_test)
# Out:
# 0.84

# %%
from sklearn.ensemble import RandomForestClassifier as RFC
rf = RFC()

# %%
rf.fit(x_train,y_train)
# Out:
# A:\ProgramData\Anaconda3\lib\site-packages\sklearn\ensemble\forest.py:245: FutureWarning: The default value of n_estimators will change from 10 in version 0.20 to 100 in 0.22.
#   "10 in version 0.20 to 100 in 0.22.", FutureWarning)
# RandomForestClassifier(bootstrap=True, class_weight=None, criterion='gini',
#                        max_depth=None, max_features='auto', max_leaf_nodes=None,
#                        min_impurity_decrease=0.0, min_impurity_split=None,
#                        min_samples_leaf=1, min_samples_split=2,
#                        min_weight_fraction_leaf=0.0, n_estimators=10,
#                        n_jobs=None, oob_score=False, random_state=None,
#                        verbose=0, warm_start=False)

# %%
rf.score(x_test,y_test)
# Out:
# 0.86

# %%
from sklearn.ensemble import GradientBoostingClassifier as GFC
gf = GFC()

# %%
gf.fit(x_train,y_train)
# Out:
# GradientBoostingClassifier(criterion='friedman_mse', init=None,
#                            learning_rate=0.1, loss='deviance', max_depth=3,
#                            max_features=None, max_leaf_nodes=None,
#                            min_impurity_decrease=0.0, min_impurity_split=None,
#                            min_samples_leaf=1, min_samples_split=2,
#                            min_weight_fraction_leaf=0.0, n_estimators=100,
#                            n_iter_no_change=None, presort='auto',
#                            random_state=None, subsample=1.0, tol=0.0001,
#                            validation_fraction=0.1, verbose=0,
#                            warm_start=False)

# %%
gf.score(x_test,y_test)
# Out:
# 0.92

# %% [markdown]
# #### THE END #####
